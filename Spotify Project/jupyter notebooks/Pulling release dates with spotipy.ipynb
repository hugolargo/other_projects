# %%
import pandas as pd

# %%
df = pd.read_csv('./global_spotify_charts.csv')
df
# Out:
#        Unnamed: 0                track_id                       song_title  \
# 0               0  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 1               1  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 2               2  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 3               3  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 4               4  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# ...           ...                     ...                              ...
# 86318       86318  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86319       86319  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86320       86320  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86321       86321  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86322       86322  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
#
#       country        date  position  streams            artists  \
# ...

# %%
track_ids = df['track_id'].unique().tolist()

# %%
len(track_ids)
# Out:
# 5987

# %%
id_set_1 = track_ids[0:1000]
id_set_2 = track_ids[1000:2000]
id_set_3 = track_ids[2000:3000]
id_set_4 = track_ids[3000:4000]
id_set_5 = track_ids[4000:5000]
id_set_6 = track_ids[5000:6000]

# %%
track_ids.remove('6dq1fUiJe6BiBORZtb9TxZ')

# %%
track_ids.remove('58wyJLv6yH1La9NIZPl3ne')

# %%
len(track_ids)
# Out:
# 5985

# %%
id_set_1
# Out:
# ['7GMeRGZax4uDKgz6wALWQw',
#  '0nrRP2bk19rLc0orkWPQk2',
#  '37zdqI4r1gswIzczSBkRon',
#  '3aWhZ1zeqy1kdjXiyMh22T',
#  '0EhpEsp4L0oRGM0vmeaN5e',
#  '3BBahK6YhmPosOymF45cMu',
#  '5Ohxk2dO5COHF1krpoPigN',
#  '1pqnQ41XbfKjaFu6M0eGJp',
#  '25B5fGr9K0VdZJiRFsnMO4',
#  '6DcDdDevI94Dh4vc5anXBE',
#  '05CwHjIk71RXVU40boRMnR',
#  '3JJYIoJ5FyY9E0DGjr7SXF',
#  '0oBtwScT4B4BR5kZitNWd5',
#  '69Naniu2KjKjaQOBUagE8U',
#  '2IRZnDFmlqMuOrYOLnZZyc',
#  '5wihevBA7MO9PNYyWyTfkh',
#  '1KFN3kB4hc6r7ILpifFsqf',
#  '6zpXc7WJ3TqYWb02B6sKyF',
#  '29m79w9xPMH4YCD6r8JSmV',
#  '2VkuxjlbnbaBiWYpdBGVol',
#  '2CeKVsFFXG4QzA415QygGb',
#  '766RKRQ1ZJjmdBQ9y54HKj',
#  '6n4U3TlzUGhdSFbUUhTvLP',
#  '6AHNkRbVzkh95xilnYzDT7',
#  '5R4Yrc2j4jw1itr4hKcN26',
#  '4kroNlz8BTfswE4M0i3YCh',
#  '0E9ZjEAyAwOXZ7wJC0PD33',
#  '07GilNHSfS5oicUgHgU7VG',
#  '2LBqCSwhJGcFQeTHMVGwy3',
#  '6kPJZM97LwdG9QIsT7khp6',
#  '11EDhDAVDtGPoSar6ootYA',
#  '6MNGxu8MprKGkchUchkJsy',
#  '1ndyl3wJCFs872XZ3ztPk6',
#  '6bqtKURdSWkInAJHDkuaL0',
# ...

# %%
id_set_1.remove('6dq1fUiJe6BiBORZtb9TxZ')

# %%
len(id_set_1)
# Out:
# 999

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
spotipy_client_id='87285ba0051e48e582cd665939d387e5'
spotipy_client_secret='26bc58c6e8204d1698152296f2cc6295'

auth_manager = SpotifyClientCredentials(spotipy_client_id, spotipy_client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
from tqdm import tqdm

# %%
import time

# %%
release_dates_1 = []

# %%
for i in tqdm(id_set_1):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates_1.append(date)
        time.sleep(1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 999/999 [20:16<00:00,  1.22s/it]

# %%
len(release_dates_1)
# Out:
# 999

# %%
release_dates_2 =[]

# %%
for i in tqdm(id_set_2[963:1000]):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates_2.append(date)
        time.sleep(1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37/37 [00:44<00:00,  1.20s/it]

# %%
len(release_dates_2)
# Out:
# 999

# %%
len(id_set_2)
# Out:
# 999

# %%
id_set_2.remove('58wyJLv6yH1La9NIZPl3ne')

# %%
len(id_set_2[925:1000])
# Out:
# 75

# %%
release_dates_3 =[]

# %%
len(id_set_3)
# Out:
# 1000

# %%
for i in tqdm(id_set_3):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates_3.append(date)
        time.sleep(1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [20:12<00:00,  1.21s/it]

# %%
len(release_dates_3)
# Out:
# 1000

# %%
len(id_set_4)
# Out:
# 1000

# %%
release_dates_4 =[]

# %%
for i in tqdm(id_set_4[206:1000]):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates_4.append(date)
        time.sleep(1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 794/794 [15:48<00:00,  1.19s/it]

# %%
len(release_dates_4) #### NOCHMAL MACHEN - wo ist der fehlende eintrag?
# Out:
# 1000

# %%
len(id_set_5)
# Out:
# 1000

# %%
release_dates_5 = []

# %%
for i in tqdm(id_set_5):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates_5.append(date)
        time.sleep(1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [20:07<00:00,  1.21s/it]

# %%
len(release_dates_5)
# Out:
# 1000

# %%
len(id_set_6)
# Out:
# 987

# %%
release_dates_6 = []

# %%
for i in tqdm(id_set_6):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates_6.append(date)
        time.sleep(1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 987/987 [19:53<00:00,  1.21s/it]

# %%
len(release_dates_6)
# Out:
# 987

# %%
# concatenate lists: 
unique_release_dates = release_dates_1 + release_dates_2 + release_dates_3 + release_dates_4 + release_dates_5 + release_dates_6

# %%
len(unique_release_dates)
# Out:
# 5985

# %%
#create new dataframe:

df_2 = pd.DataFrame(list(zip(track_ids, unique_release_dates)), columns =['track_id', 'release_date'])

# %%
df_2
# Out:
#                     track_id release_date
# 0     7GMeRGZax4uDKgz6wALWQw   2014-08-29
# 1     0nrRP2bk19rLc0orkWPQk2   2013-01-01
# 2     37zdqI4r1gswIzczSBkRon   2019-10-25
# 3     3aWhZ1zeqy1kdjXiyMh22T   2016-07-28
# 4     0EhpEsp4L0oRGM0vmeaN5e   2020-07-24
# ...                      ...          ...
# 5980  7MiZjKawmXTsTNePyTfPyL   2016-02-05
# 5981  79reBHqpRoWXaQbjBBY3UC   2015-03-02
# 5982  7wqSzGeodspE3V6RBD5W8L   2015-03-10
# 5983  2Y0wPrPQBrGhoLn14xRYCG   2020-07-10
# 5984  790MhTXPFrYkrqCKvpg4t1   2017-11-03
#
# [5985 rows x 2 columns]

# %%
df_2.to_csv('unique_track_release_dates.csv')

# %%
df_2.isnull().sum()
# Out:
# track_id        0
# release_date    0
# dtype: int64

# %%
df
# Out:
#        Unnamed: 0                track_id                       song_title  \
# 0               0  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 1               1  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 2               2  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 3               3  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 4               4  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# ...           ...                     ...                              ...
# 86318       86318  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86319       86319  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86320       86320  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86321       86321  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86322       86322  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
#
#       country        date  position  streams            artists  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# song_title          1
# country             0
# date                0
# position            0
# streams             0
# artists             0
# artist_genres       0
# duration_minutes    0
# explicit            0
# year                0
# month               0
# dtype: int64

# %%
# merge tables:
df_new = df.merge(df_2, how= 'inner', on='track_id')

# %%
df_new
# Out:
#        Unnamed: 0                track_id                       song_title  \
# 0               0  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 1               1  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 2               2  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 3               3  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 4               4  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# ...           ...                     ...                              ...
# 86291       86318  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86292       86319  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86293       86320  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86294       86321  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86295       86322  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
#
#       country        date  position  streams            artists  \
# ...

# %%
df_new.to_csv('global_with_release_dates.csv')

# %%
df_new_left = df.merge(df_2, how= 'left', on='track_id')
df_new_left
# Out:
#        Unnamed: 0                track_id                       song_title  \
# 0               0  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 1               1  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 2               2  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 3               3  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 4               4  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# ...           ...                     ...                              ...
# 86318       86318  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86319       86319  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86320       86320  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86321       86321  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86322       86322  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
#
#       country        date  position  streams            artists  \
# ...

# %%
df_new_left.isnull().sum()
# Out:
# Unnamed: 0           0
# track_id             0
# song_title           1
# country              0
# date                 0
# position             0
# streams              0
# artists              0
# artist_genres        0
# duration_minutes     0
# explicit             0
# year                 0
# month                0
# release_date        27
# dtype: int64

# %%
df_new_left.loc[df_new_left['release_date'].isnull()]
# Out:
#        Unnamed: 0                track_id            song_title country  \
# 2861         2861  6dq1fUiJe6BiBORZtb9TxZ  INTERMISSION: fLoWer  global
# 27944       27944  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27945       27945  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27946       27946  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27947       27947  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27948       27948  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27949       27949  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27950       27950  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27951       27951  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27952       27952  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27953       27953  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# 27954       27954  58wyJLv6yH1La9NIZPl3ne  Can We Kiss Forever?  global
# ...

# %%
df_new.sample(30)
# Out:
#        Unnamed: 0                track_id  \
# 45804       45831  2Fxmhks0bxGSBdJ92vM42m
# 69528       69555  5w9c2J52mkdntKOmRLeM2m
# 79508       79535  3rq5w4bQGigXOfdN30ATJt
# 64184       64211  7KXjTSCq5nL1LoYtL7XAwS
# 60663       60690  167NczpNbRF7oWakJaY3Hh
# 52175       52202  32OlwWuMpZ6b0aN2RZOeMS
# 51975       52002  2JvzF1RMd7lE3KmFlsyZD8
# 56239       56266  0u2P5u6lvoDfwTYjAADbn4
# 80156       80183  2lCkncy6bIB0LTMT7kvrD1
# 68207       68234  7rglLriMNBPAyuJOMGwi39
# 36679       36706  1wZqJM5FGDEl3FjHDxDyQd
# 33073       33100  6UjfByV1lDLW0SOVQA4NAi
# 38080       38107  6jfEZdUJ2Yla6h7gTJgKuo
# 69546       69573  5w9c2J52mkdntKOmRLeM2m
# 64104       64131  7KXjTSCq5nL1LoYtL7XAwS
# 24676       24677  7dt6x5M1jzdTEt8oCbisTK
# 56716       56743  71ywEs45ClmTNRiaJ7YEsr
# 55312       55339  4ToSbnK7fD5vE9R5sgWPsy
# 27653       27654  4HBZA5flZLE435QTztThqH
# 49150       49177  2b8fOow8UzyDFAE27YhOZM
# 67239       67266  3qCeq0rWK67SoBDgFd2sId
# ...
