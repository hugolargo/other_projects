# %%
import pandas as pd

# %%
df = pd.read_csv('../data/countries_data_with_iso.csv', index_col = [0])
df
# Out:
#                        track_id          song_title country        date  \
# 0        20IvMlpi4U5RuDnAlXSRiV          Crackküche      de  2021-04-15
# 1        0V1K6MU0utODk4yNqZKsFv               WATER      jp  2019-01-31
# 2        4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-15
# 3        4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-22
# 4        4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-29
# ...                         ...                 ...     ...         ...
# 5299303  7731grGgxDd7aBNpGOjm9k    När löven faller      se  2019-11-28
# 5299304  4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-17
# 5299305  4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-24
# 5299306  4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-31
# 5299307  1selIVe40h0Ak2GVCzg5si   Digital Kærlighed      dk  2020-04-02
#
#          position  streams              artists  \
# 0              82   625718           Haftbefehl
# ...

# %%
df.head()
# Out:
#                  track_id          song_title country        date  position  \
# 0  20IvMlpi4U5RuDnAlXSRiV          Crackküche      de  2021-04-15        82
# 1  0V1K6MU0utODk4yNqZKsFv               WATER      jp  2019-01-31       171
# 2  4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-15        59
# 3  4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-22       133
# 4  4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-29       166
#
#    streams     artists                                      artist_genres  \
# 0   625718  Haftbefehl                                 ['german hip hop']
# 1    50896     Suchmos  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2   185439    Nilipek.      ['turkish singer-songwriter', 'turkish rock']
# 3   111159    Nilipek.      ['turkish singer-songwriter', 'turkish rock']
# 4    96204    Nilipek.      ['turkish singer-songwriter', 'turkish rock']
#
#    duration_minutes  explicit  year  month iso_alpha
# ...

# %%
df_global = pd.read_csv('../data/global_with_release_dates.csv', index_col = [0])

# %%
df_global
# Out:
#        Unnamed: 0                track_id                       song_title  \
# 0               0  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 1               1  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 2               2  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 3               3  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# 4               4  7GMeRGZax4uDKgz6wALWQw                It Was Always You
# ...           ...                     ...                              ...
# 86291       86318  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86292       86319  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86293       86320  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86294       86321  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
# 86295       86322  790MhTXPFrYkrqCKvpg4t1  Wanted You (feat. Lil Uzi Vert)
#
#       country        date  position  streams            artists  \
# ...

# %%
df_original = pd.read_csv('../data/original_dataset.csv', index_col = [0])
df_original
# Out:
#                                       name country        date  position  \
# track_id
# 20IvMlpi4U5RuDnAlXSRiV          Crackküche      de  2021-04-15        82
# 0V1K6MU0utODk4yNqZKsFv               WATER      jp  2019-01-31       171
# 4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-15        59
# 4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-22       133
# 4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-29       166
# ...                                    ...     ...         ...       ...
# 7731grGgxDd7aBNpGOjm9k    När löven faller      se  2019-11-28       163
# 4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-17       161
# 4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-24       139
# 4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-31       151
# 1selIVe40h0Ak2GVCzg5si   Digital Kærlighed      dk  2020-04-02       172
#
#                         streams                  artists  \
# track_id
# ...

# %%
print(df_global.head().to_markdown())
# Out:
# |    |   Unnamed: 0 | track_id               | song_title        | country   | date       |   position |   streams | artists   | artist_genres   |   duration_minutes | explicit   |   year |   month | release_date   |
# |---:|-------------:|:-----------------------|:------------------|:----------|:-----------|-----------:|----------:|:----------|:----------------|-------------------:|:-----------|-------:|--------:|:---------------|
# |  0 |            0 | 7GMeRGZax4uDKgz6wALWQw | It Was Always You | global    | 2014-09-07 |         44 |   2858282 | Maroon 5  | ['pop']         |            3.99867 | False      |   2014 |       9 | 2014-08-29     |
# |  1 |            1 | 7GMeRGZax4uDKgz6wALWQw | It Was Always You | global    | 2014-09-14 |         42 |   3010512 | Maroon 5  | ['pop']         |            3.99867 | False      |   2014 |       9 | 2014-08-29     |
# ...
