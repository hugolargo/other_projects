# %%
import pandas as pd
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
spotipy_client_id='87285ba0051e48e582cd665939d387e5'
spotipy_client_secret='26bc58c6e8204d1698152296f2cc6295'

auth_manager = SpotifyClientCredentials(spotipy_client_id, spotipy_client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
urn = 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'

artist = sp.artist(urn)
artist
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  'followers': {'href': None, 'total': 60049452},
#  'genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#  'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebb5f9e28219c169fd4b9e8379',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174b5f9e28219c169fd4b9e8379',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178b5f9e28219c169fd4b9e8379',
#    'width': 160}],
#  'name': 'The Weeknd',
#  'popularity': 99,
#  'type': 'artist',
#  'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}

# %%
sp = spotipy.Spotify(auth_manager=auth_manager)

urn = 'spotify:artist:4KWTAlx2RvbpseOGMEmROg'



artist = sp.artist(urn)
artist

# %%
from tqdm import tqdm

# %%
df = pd.read_csv('./charts.csv')
df
# Out:
#                        track_id                name country        date  \
# 0        20IvMlpi4U5RuDnAlXSRiV          Crackküche      de  2021-04-15
# 1        0V1K6MU0utODk4yNqZKsFv               WATER      jp  2019-01-31
# 2        4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-15
# 3        4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-22
# 4        4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-29
# ...                         ...                 ...     ...         ...
# 5299303  7731grGgxDd7aBNpGOjm9k    När löven faller      se  2019-11-28
# 5299304  4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-17
# 5299305  4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-24
# 5299306  4Vm9XIi9AD1oK39xACmqk5        ワガママで誤魔化さないで      jp  2019-01-31
# 5299307  1selIVe40h0Ak2GVCzg5si   Digital Kærlighed      dk  2020-04-02
#
#          position  streams                  artists  \
# ...

# %%
df_ger = df[df['country']=='de']
df_ger
# Out:
#                        track_id                      name country        date  \
# 0        20IvMlpi4U5RuDnAlXSRiV                Crackküche      de  2021-04-15
# 21       5m4y68zsFwsix7ng4cLB1j                 Teamgeist      de  2015-12-03
# 22       5m4y68zsFwsix7ng4cLB1j                 Teamgeist      de  2015-12-10
# 23       5m4y68zsFwsix7ng4cLB1j                 Teamgeist      de  2015-12-17
# 62       3UPXsxC1h5bPuXhBMAcWo7             NEXTLEVELSHIT      de  2016-11-03
# ...                         ...                       ...     ...         ...
# 5299146  20opc3dykV1sSxVwaGLUMc                     Warum      de  2020-09-10
# 5299147  20opc3dykV1sSxVwaGLUMc                     Warum      de  2020-09-17
# 5299148  20opc3dykV1sSxVwaGLUMc                     Warum      de  2020-09-24
# 5299149  20opc3dykV1sSxVwaGLUMc                     Warum      de  2020-10-01
# 5299186  7nhRvNTtuNPWvJuEnmNJYb  Voyage Skit (feat. Gzuz)      de  2022-10-06
#
# ...

# %%
df_ger.reset_index(inplace=True)

# %%
df_ger.head()
# Out:
#    index                track_id           name country        date  position  \
# 0      0  20IvMlpi4U5RuDnAlXSRiV     Crackküche      de  2021-04-15        82
# 1     21  5m4y68zsFwsix7ng4cLB1j      Teamgeist      de  2015-12-03        43
# 2     22  5m4y68zsFwsix7ng4cLB1j      Teamgeist      de  2015-12-10        54
# 3     23  5m4y68zsFwsix7ng4cLB1j      Teamgeist      de  2015-12-17       102
# 4     62  3UPXsxC1h5bPuXhBMAcWo7  NEXTLEVELSHIT      de  2016-11-03       186
#
#    streams         artists                                artist_genres  \
# 0   625718  ['Haftbefehl']                           ['german hip hop']
# 1   444549  ['Alligatoah']                               ['german pop']
# 2   343488  ['Alligatoah']                               ['german pop']
# 3   214546  ['Alligatoah']                               ['german pop']
# 4   169363    ['DAT ADAM']  ['german cloud rap', 'deep german hip hop']
#
#    duration  explicit
# 0    198746     False
# ...

# %%
df.head()
# Out:
#                  track_id                name country        date  position  \
# 0  20IvMlpi4U5RuDnAlXSRiV          Crackküche      de  2021-04-15        82
# 1  0V1K6MU0utODk4yNqZKsFv               WATER      jp  2019-01-31       171
# 2  4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-15        59
# 3  4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-22       133
# 4  4qzZm5EIdFurBpDieEmVc9  Gözleri Aşka Gülen      tr  2018-11-29       166
#
#    streams         artists                                      artist_genres  \
# 0   625718  ['Haftbefehl']                                 ['german hip hop']
# 1    50896     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2   185439    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3   111159    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    96204    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit
# ...

# %%
test = df['track_id'].unique()

# %%
test = test.tolist()

# %%
test
# Out:
# ['20IvMlpi4U5RuDnAlXSRiV',
#  '0V1K6MU0utODk4yNqZKsFv',
#  '4qzZm5EIdFurBpDieEmVc9',
#  '1vWrdDoVve3adC23brWRke',
#  '0N8PEQ33Ba841py3SEV0Wp',
#  '6BIfloI765jfr51Se2xSdw',
#  '5m4y68zsFwsix7ng4cLB1j',
#  '5NcTOxzo2WE20tFdtUhbAM',
#  '3UPXsxC1h5bPuXhBMAcWo7',
#  '278flqoZwDROtHCn2KVBbq',
#  '0YgvF6fNWydNGzCY3pzK4Y',
#  '7GMeRGZax4uDKgz6wALWQw',
#  '4jGzR5Vri06Y5T9SxM7m5P',
#  '3p8VuChjDae8lY7fx91Esy',
#  '39lwTKgwElmhkUlppFH8AR',
#  '6hEpJtKf1YDaIqRdjNCPFW',
#  '6xWqaVbmZJqEbUpFlIGiHK',
#  '7BvfnAXIk7LBrUvbSRXhjR',
#  '6tuyca2iIhPrORZkTOQNrZ',
#  '2jZQxvy1T9iWl5u4Id53tp',
#  '0LMKvOt3vDHYj5XGiOMDdZ',
#  '4NLfKIsRhP1cve1kcrYg40',
#  '2Bv0MbaqYx2IrQa7Z6xBT0',
#  '2NUlvZqTgkLl3YsWVMZ7vA',
#  '1QAvz1VWNFbZeRWSCFyew2',
#  '5RsAjYLZdkknFgke7Hv452',
#  '2wBB2KKqtuK1fcxAiqbCSZ',
#  '0P1lIvhkh6vBW4c5dqzuiC',
#  '01AHLmTHZb7MbkxG6X1UjK',
#  '0cNxKglSkBx1cJb2PAB21a',
#  '5srlU62BkGl2VxfuuEgOYi',
#  '47ShOa6IM06ff7SnK6crab',
#  '49dwc91esnpPYpVNPS01bX',
#  '25P7sBSswuS5d3QcnpBTiH',
# ...

# %%
unique_ids = test

# %%
len(unique_ids)
# Out:
# 102947

# %%
id_set_1 = unique_ids[0:1000]
id_set_2 = unique_ids[1000:2000]
id_set_3 = unique_ids[2000:3000]
id_set_4 = unique_ids[3000:4000]
id_set_5 = unique_ids[4000:5000]

# %%
len(id_set_1)
# Out:
# 1000

# %%
from tqdm import tqdm
import time

import traceback

release_dates = []

# %%
for i in tqdm(id_set_1):
        urn = f'spotify:track:{i}'
        track = sp.track(urn)
        date = track['album']['release_date']
        release_dates.append(date)
        time.sleep(1)
# Out:
#   0%|                                                                                         | 0/1000 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/dm/dh2ljx393fj9vntx4cdh0vsh0000gn/T/ipykernel_3308/1388530053.py in <module>
#       1 for i in tqdm(id_set_1):
#       2         urn = f'spotify:track:{i}'
# ----> 3         track = sp.track(urn)
#       4         date = track['album']['release_date']
#       5         release_dates.append(date)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in track(self, track_id, market)
#     367
#     368         trid = self._get_id("track", track_id)
# --> 369         return self._get("tracks/" + trid, market=market)
#     370
#     371     def tracks(self, tracks, market=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
# ...

# %%
urn = 'spotify:track:3YBZIN3rekqsKxbJc9FZko'

track = sp.track(urn)
track['album']['release_date']

# %%
release_dates
# Out:
# ['2021-04-08',
#  '2015-11-27',
#  '2015-11-27',
#  '2015-11-27',
#  '2016-10-28',
#  '2016-08-12',
#  '2022-08-05',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01',
#  '2013-01-01']

# %%
len(release_dates)
# Out:
# 1
